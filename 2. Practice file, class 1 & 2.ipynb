# %% [markdown]
# # operations on string

# %%
a= 'akshay'
b= 'pandit'

print(type(a))
print(type(b))
# Out:
# <class 'str'>
# <class 'str'>

# %%
print(a + ' ' + b)
# Out:
# akshay pandit

# %%
a.capitalize()
# Out:
# 'Akshay'

# %%
b.capitalize()
# Out:
# 'Pandit'

# %%
a.casefold()
# Out:
# 'akshay'

# %%
a.count('a')
# Out:
# 2

# %%
b.count('a')
# Out:
# 1

# %%
print(len(a))
print(len(b))
# Out:
# 6
# 6

# %%
b= 'Bharata'

# %%
b[0]
# Out:
# 'B'

# %%
b[0:]
# Out:
# 'Bharata'

# %%
b[0:4]
# Out:
# 'Bhar'

# %%
b[-1]
# Out:
# 'a'

# %%
b[::-1]
# Out:
# 'atarahB'

# %%
b[-5:-1]
# Out:
# 'arat'

# %%
a = 'ratan'
a.find('a')
# Out:
# 1

# %%
a.capitalize()
# Out:
# 'Ratan'

# %%
print(a.upper())
print(a.lower())
print(a.title())
# Out:
# RATAN
# ratan
# Ratan

# %%
print(a.isupper())
print(a.islower())
# Out:
# False
# True

# %%
w=  '   akshaylovesPriya  '

# %%
w.strip()
# Out:
# 'akshaylovesPriya'

# %%
w.lstrip()
# Out:
# 'akshaylovesPriya  '

# %%
w.rstrip()
# Out:
# '   akshaylovesPriya'

# %%
t = 'i love Bharat'

t.replace('Bharat','India')
# Out:
# 'i love India'

# %%
q= 'ind,aus,nz'
print(q.split(','))
# Out:
# ['ind', 'aus', 'nz']

# %%
q.split
# Out:
# <function str.split(sep=None, maxsplit=-1)>

# %%
print(''.join(q))
# Out:
# ind,aus,nz

# %%
g = 'i am learning python'
print('rnin' in g)
# Out:
# True

# %%
y = 'Akshay'
print(y.replace('Akshay','Amy'))
print(y)
# Out:
# Amy
# Akshay

# %%
a = 'Bar'
a='C' + a[1:]
print(a)
# Out:
# Car

# %%
print(a)
# Out:
# Car
