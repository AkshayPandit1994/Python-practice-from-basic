# %% [raw]
# list()
# isinstance()
# append()
# extend()
# copy()

# %% [markdown]
# # list

# %%
[]
# Out:
# []

# %%
l = (1,2,3,4,5)
print(l)
# Out:
# (1, 2, 3, 4, 5)

# %%
print(type(l))
# Out:
# <class 'tuple'>

# %%
type(l)
# Out:
# tuple

# %%
m = list(l)
print(m)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(type(m))
# Out:
# <class 'list'>

# %%
l = list(l)
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
code = ['I','watch','IPL','matches']

# %%
print(code)
# Out:
# ['I', 'watch', 'IPL', 'matches']

# %%
code[0]
# Out:
# 'I'

# %%
code[1]
# Out:
# 'watch'

# %%
code[2]
# Out:
# 'IPL'

# %%
code[3]
# Out:
# 'matches'

# %%
code[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 code[4]
#
# IndexError: list index out of range

# %%
# list in list

# %%
y = [10,20,30,[15,25,35],40,50,60]
print(y)
# Out:
# [10, 20, 30, [15, 25, 35], 40, 50, 60]

# %%
y[0]
# Out:
# 10

# %%
y[2]
# Out:
# 30

# %%
y[3]
# Out:
# [15, 25, 35]

# %%
y[3],[0]
# Out:
# ([15, 25, 35], [0])

# %%
y[3][0]
# Out:
# 15

# %%
y[3][1]
# Out:
# 25

# %%
y[3][2]
# Out:
# 35

# %%
y[3][3]           # list index finished
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 y[3][3]
#
# IndexError: list index out of range

# %%
y[4]
# Out:
# 40

# %%
y[5]
# Out:
# 50

# %%
y[6]
# Out:
# 60

# %%
y[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 y[7]
#
# IndexError: list index out of range

# %%
print(y[3])
# Out:
# [15, 25, 35]

# %%
print(y[3][0])
# Out:
# 15

# %%
print(y)
# Out:
# [10, 20, 30, [15, 25, 35], 40, 50, 60]

# %%
print(y[-1])
# Out:
# 60

# %%
print(y[-2])
# Out:
# 50

# %%
print(y[-1:-4])
# Out:
# []

# %%
print(y[-4:-1])
# Out:
# [[15, 25, 35], 40, 50]

# %%
print(y[:-1])
# Out:
# [10, 20, 30, [15, 25, 35], 40, 50]

# %%
print(y[::-1])                       # reverse oder
# Out:
# [60, 50, 40, [15, 25, 35], 30, 20, 10]

# %%
y
# Out:
# [10, 20, 30, [15, 25, 35], 40, 50, 60]

# %%
y.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 y.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
nl= []

for i in y:
    if isinstance(i, list):
        nl.extend(i)
    else:
        nl.append(i)
print(nl.sort())            # it return none beacause of print syatement, see below eample
print(nl)
# Out:
# None
# [10, 15, 20, 25, 30, 35, 40, 50, 60]

# %%
nl= []

for i in y:
    if isinstance(i, list):
        nl.extend(i)
    else:
        nl.append(i)
nl.sort()
print(nl)
# Out:
# [10, 15, 20, 25, 30, 35, 40, 50, 60]

# %%
z= [88,55,77,11,100,23,56,87,45,85]

# %%
z.sort()
print(z)
# Out:
# [11, 23, 45, 55, 56, 77, 85, 87, 88, 100]

# %%
# copy operation on list

# %%
a= [10,11,12,13]
b=a                  # this is not actual copy, this is assigning operation
print(b)
# Out:
# [10, 11, 12, 13]

# %%
a.append(14)
print(a,b)             # it changes both list a, b, however we make changes on a only
# Out:
# [10, 11, 12, 13, 14, 14] [10, 11, 12, 13, 14, 14]

# %%
c=[77,78,79,80]
d=c.copy()
print(d)
# Out:
# [77, 78, 79, 80]

# %%
c.insert(0,76)
print(c,d)            # here copied element is remain unchanged
# Out:
# [76, 76, 77, 78, 79, 80] [77, 78, 79, 80]

# %%
# cocatenation

# %%
j = 101,102,103,104
k= 'i','love','python'
print(j+k)
# Out:
# (101, 102, 103, 104, 'i', 'love', 'python')

# %%
type(j)
# Out:
# tuple

# %%
type(k)
# Out:
# tuple

# %%
j = 101,102,103,104
k= ['i','love','python']
print(j+k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 3
#       1 j = 101,102,103,104
#       2 k= ['i','love','python']
# ----> 3 print(j+k)
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
j = [101,102,103,104]          # both need to string
k= ['i','love','python']
print(j+k)
# Out:
# [101, 102, 103, 104, 'i', 'love', 'python']

# %%
j
# Out:
# [101, 102, 103, 104]

# %%
j[0]
# Out:
# 101

# %%
j[0]=100                      # list is mutable/value can be change
j
# Out:
# [100, 102, 103, 104]

# %%
p = 'Python'
p
# Out:
# 'Python'

# %%
p[0]
# Out:
# 'P'

# %%
p[0].= 'T'
# Out:
#   Cell In[103], line 1
#     p[0].= 'T'
#          ^
# SyntaxError: invalid syntax

# %%
g=p[0].replace('z', 'Y')
print(g)
# Out:
# P

# %%
p
# Out:
# 'Python'

# %%
t= ['I','like','java']
print(t)
# Out:
# ['I', 'like', 'java']

# %%
t[2]
# Out:
# 'java'

# %%
t[2] = 'python'           # it changes here as we make changes on list
t
# Out:
# ['I', 'like', 'python']

# %%
t[0:1]= ['i','work on']
t
# Out:
# ['i', 'work on', 'like', 'python']

# %%
t[0:3]= ['i','work on']
t
# Out:
# ['i', 'work on', 'python']

# %%
t[0:4]= ['i','work on']
t
# Out:
# ['i', 'work on']

# %%
t[0]
# Out:
# 'i'

# %%
t[0:5]= ['i','work on']
t
# Out:
# ['i', 'work on']

# %%
t[0:99]= ['i','work on']
t
# Out:
# ['i', 'work on']

# %%
t
# Out:
# ['i', 'work on']

# %%
type(t)
# Out:
# list

# %%
t.append('Python')
t
# Out:
# ['i', 'work on', 'Python']

# %% [raw]
# # key concept
# # In slicing assignment:
#
# # You can replace multiple elements with fewer or more elements
# # List size can change dynamically

# %%
q = [11,12,15,16,17]
q[1:2]=14
q
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 2
#       1 q = [11,12,15,16,17]
# ----> 2 q[1:2]=14
#       3 q
#
# TypeError: must assign iterable to extended slice

# %%
q = [11,12,15,16]              # list size changes
q[1:2]=[14]
q
# Out:
# [11, 14, 15, 16]

# %%
len(q)
# Out:
# 4

# %%
q.append(17)
print(q)
# Out:
# [11, 14, 15, 16, 17]

# %%
q.count
# Out:
# <function list.count(value, /)>

# %%
q.count(11)         # it will answer no of given data in list - occurance number
# Out:
# 1

# %%
len(q)
# Out:
# 5

# %%
q
# Out:
# [11, 14, 15, 16, 17]

# %%
p=[20,21,22]

# %%
q.extend(p)            # it will add another list at end

# %%
q
# Out:
# [11, 14, 15, 16, 17, 20, 21, 22]

# %%
q.index(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 q.index(5)
#
# ValueError: 5 is not in list

# %%
q.index(21)         # 21 ia listed at posion 6
# Out:
# 6

# %%
q
# Out:
# [11, 14, 15, 16, 17, 20, 21, 22]

# %%
q.insert(6,29)
q
# Out:
# [11, 14, 15, 16, 17, 20, 29, 21, 22]

# %%
q.pop()
# Out:
# 22

# %%
q              # last digit removes
# Out:
# [11, 14, 15, 16, 17, 20, 29, 21]

# %%
q.remove(21)
q
# Out:
# [11, 14, 15, 16, 17, 20, 29]

# %%
q.reverse()
q
# Out:
# [11, 14, 15, 16, 17, 20, 29]

# %%
q
# Out:
# [11, 14, 15, 16, 17, 20, 29]

# %%
q.reverse()
q
# Out:
# [11, 14, 15, 16, 17, 20, 29]

# %%
q.sort()
q
# Out:
# [11, 14, 15, 16, 17, 20, 29]

# %%
a= ['i', 'like', 'cricket']

# %%
a
# Out:
# ['i', 'like', 'cricket']

# %%
print(a)
# Out:
# ['i', 'like', 'cricket']

# %%
del(a)      # it will delete given list

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
# if with list

# %%
new_list = ["IND","SA", "AUS", "NZ"]

if 'SA' in new_list:            # case  sensitive
    print('present')
else:
    print('missing')
# Out:
# present

# %%
j = list[1,2,3]
j
# Out:
# list[1, 2, 3]

# %%
print(j)
# Out:
# list[1, 2, 3]

# %%
k = list(1,2,3,4)          # incorrect input
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 k = list(1,2,3,4)
#
# TypeError: list expected at most 1 argument, got 4

# %%
k = list((1,2,3,4))
k
# Out:
# [1, 2, 3, 4]
