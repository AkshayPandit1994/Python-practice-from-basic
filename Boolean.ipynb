# %%
# Boolean NUmbers: it is a data type with only 2 values

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True - True
# Out:
# 0

# %%
True + False
# Out:
# 1

# %%
True - False
# Out:
# 1

# %%
False - True
# Out:
# -1

# %%
False - False
# Out:
# 0

# %% [raw]
# Boolean with comparision operators
#
# ==   # equal
# !=   # not equal
# >    # greater than
# <    # less than
# >=   # greater or equal
# <=   # less or equal

# %%
d= 95
e=97

# %%
print(d>e)
# Out:
# False

# %%
print(d<e)
# Out:
# True

# %%
print('a'>'b')
# Out:
# False

# %%
print('z'<'y')
# Out:
# False

# %%
print('z'<'z')
# Out:
# False

# %%
print('z'<='z')
# Out:
# True

# %%
print('z'=='z')
# Out:
# True

# %%
print('a'=='b')
# Out:
# False

# %%
print('a'!='b')
# Out:
# True

# %%
r= 78
y =96

print('r'>='y')
# Out:
# False

# %%
print('r'<='y')
# Out:
# True

# %%
print(True and True)
# Out:
# True

# %%
print(True and False)
# Out:
# False

# %%
print(False and False)
# Out:
# False

# %%
print(True or False)
# Out:
# True

# %%
print(False or True)
# Out:
# True

# %%
print(False or False)
# Out:
# False

# %%
age = 17

if age>=18:
    print('Adult')
else:
    print('Minor')
# Out:
# Minor

# %%
age = 19

if age>=18:
    print('Adult')
else:
    print('Minor')
# Out:
# Adult

# %%
age = 199

if age>100:
    print('Please enter valid Age')

if age>=18:
        print('Adult')
else:
    print('Minor')
# Out:
# Please enter valid Age
# Adult

# %%
age = 18

if age > 100:
    print('Please enter valid Age')
elif age >= 18:
    print('Adult')
else:
    print('Minor')
# Out:
# Adult

# %%
if 'Akshay':
    print('Hello')
# Out:
# Hello

# %%
print(bool(0))
# Out:
# False

# %%
print(bool(1))
# Out:
# True

# %%
print(bool(0.1))
# Out:
# True

# %%
print(bool(-0.1))
# Out:
# True

# %%
print(bool(-0.01))
# Out:
# True

# %%
print(bool(""))
# Out:
# False

# %%
print(bool("Akshay"))
# Out:
# True

# %%
x=0
y=5

print(x and y)
print(x or y)          #  Python returns actual value, not just True/False
# Out:
# 0
# 5

# %%
print(2 in [1,2,3,4])
# Out:
# True

# %%
x = None
print(x is None)
# Out:
# True

# %%
print(x is not None)
# Out:
# False

# %%
s= 15

print(9<s<20)
# Out:
# True
