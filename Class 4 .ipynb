# %% [raw]
# Arithmetic Operators
# iterator
# next
# for
# range

# %%
10+10
# Out:
# 20

# %%
20-10
# Out:
# 10

# %%
20*10
# Out:
# 200

# %%
20/10
# Out:
# 2.0

# %%
20%3                      # returns reminder
# Out:
# 2

# %%
20//3                     # returns divide by number
# Out:
# 6

# %%
2**2
# Out:
# 4

# %%
6**2
# Out:
# 36

# %%
6**6
# Out:
# 46656

# %%
6*6*6*6*6*6
# Out:
# 46656

# %%
import math

print(math.floor(10.99))
# Out:
# 10

# %%
print(math.floor(10.1))
# Out:
# 10

# %%
print(math.floor(-10.99))
# Out:
# -11

# %%
print(math.floor(-10.49))
# Out:
# -11

# %%
print(math.floor(-10.01))
# Out:
# -11

# %%
# Floor division math.floor() → Rounds down to nearest integer Floor always moves down, even for negative numbers

# %%
# string operations

# %%
print("apple" == "apple")
# Out:
# True

# %%
print("apple" == "Apple")       # case sensitive
# Out:
# False

# %%
print("apple" >= "banana")
# Out:
# False

# %%
print("apple" <= "banana")
# Out:
# True

# %%
print("apple" < "banana")
# Out:
# True

# %%
print("apple" != "banana")
# Out:
# True

# %%
print('a' in 'banana')
# Out:
# True

# %%
print('x' in 'banana')
# Out:
# False

# %%
print('x' not in 'banana')
# Out:
# True

# %%
print(3 in [1,2,3,4,5])
# Out:
# True

# %%
print(33 in [1,2,3,4,5])
# Out:
# False

# %%
print("a" in ("a", "x", "t"))
# Out:
# True

# %%
print(2 in{1,5,2,3,2})
# Out:
# True

# %%
data = {'name':'akshay', 'age':22}

print('age' in data)
# Out:
# True

# %%
data = {'name':'akshay', 'age':22}

print(22 in data)         # it will check keys only
# Out:
# False

# %%
print(22 in data.values())     # need to check with values
# Out:
# True

# %%
print(5 in 12345)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 print(5 in 12345)
#
# TypeError: argument of type 'int' is not iterable

# %%
print(5 in [1,2,3,4,5])
# Out:
# True

# %%
n= 'data analyst'
n
# Out:
# 'data analyst'

# %%
for i in n:
    print(i)
# Out:
# d
# a
# t
# a
#
# a
# n
# a
# l
# y
# s
# t

# %%
i = iter(n)            # it returns address where it located in memory
print(i)

# %% [markdown]
# ## iterator, next

# %%
my_list = [10,20,30,40]
print(my_list)
# Out:
# [10, 20, 30, 40]

# %%
for i in my_list:
    print(i)
# Out:
# 10
# 20
# 30
# 40

# %%
for i in enumerate(my_list):
    print(i)
# Out:
# (0, 10)
# (1, 20)
# (2, 30)
# (3, 40)

# %%
iterator = iter(my_list)
print(iterator)
iterator

# %%
print(next(iterator))
# Out:
# 10

# %%
print(next(iterator))
# Out:
# 20

# %%
print(next(iterator))
# Out:
# 30

# %%
print(next(iterator))
# Out:
# 40

# %%
print(next(iterator))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 print(next(iterator))
#
# StopIteration:

# %% [markdown]
# ## for()

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(3):
    for j in range(3):
        print('*',end= ' ')
    print()
# Out:
# * * *
# * * *
# * * *

# %%
for i in range(3):
    for j in range(3):
        print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2

# %%
for i in range(5,15,3):
    print(i)
# Out:
# 5
# 8
# 11
# 14

# %%
for i in [5,15,25,35]:
    print(i)
# Out:
# 5
# 15
# 25
# 35

# %%
for tpl in (90,80,70):
    print(tpl)
# Out:
# 90
# 80
# 70

# %%
datas = {"Name": "Apriya", "Age": 30}

for i in datas:
    print(i, (datas.values()))
# Out:
# Name dict_values(['Apriya', 30])
# Age dict_values(['Apriya', 30])

# %%
datas = {"Name": "Apriya", "Age": 30}

for i in datas:
    print(i, datas[i])
# Out:
# Name Apriya
# Age 30

# %%
datas = {"Name": "Apriya", "Age": 30}

for i in datas:
    print(datas[i])
# Out:
# Apriya
# 30

# %%
for v in datas.values():
    print(v)
# Out:
# Apriya
# 30

# %%
for k,v in datas.items():
    print(k,v)
# Out:
# Name Apriya
# Age 30

# %%
for i in range(6):
    if i ==4:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(6):
    if i ==4:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 5
