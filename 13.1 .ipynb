# %% [markdown]
# # tuple()

# %%
a= ()

# %%
type(a)
# Out:
# tuple

# %%
a=('b')           # its string
type(a)
# Out:
# str

# %%
b= ('c','d')        # for tuple it must contain 2 values
type(b)
# Out:
# tuple

# %%
f = (1)

# %%
type(f)
# Out:
# int

# %%
g=(10,20)            # same like string, we can work on integer also
type(g)
# Out:
# tuple

# %%
h= (1,2,3,10.5, 5+5j, 'a','Z','Akshay','Anagar@2026')

# %%
type(h)
# Out:
# tuple

# %%
# slicing

# %%
h[0]
# Out:
# 1

# %%
h[1]
# Out:
# 2

# %%
h[99]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 h[99]
#
# IndexError: tuple index out of range

# %%
h[-1]
# Out:
# 'Anagar@2026'

# %%
h[2:6]
# Out:
# (3, 10.5, (5+5j), 'a')

# %%
h[::-1]                    # reverse tuple
# Out:
# ('Anagar@2026', 'Akshay', 'Z', 'a', (5+5j), 10.5, 3, 2, 1)

# %%
h[-4:-1]
# Out:
# ('a', 'Z', 'Akshay')

# %%
h
# Out:
# (1, 2, 3, 10.5, (5+5j), 'a', 'Z', 'Akshay', 'Anagar@2026')

# %%
h.index('a')
# Out:
# 5

# %%
h.count(9)         # count of given value
# Out:
# 0

# %%
# if () with tuple

# %%
if 10.5 in h:
    print('present')
else:
    print('missing')
# Out:
# present

# %%
if 'data' in h:
    print('present')
else:
    print('missing')
# Out:
# missing

# %%
# tuple does not support assignment

# %%
r= ('data', 'science')
type(r)
# Out:
# tuple

# %%
r[0]
# Out:
# 'data'

# %%
r[1]
# Out:
# 'science'

# %%
r[1] = 'Analyst'          # error ocure as it does not suppport assignment like list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 r[1] = 'Analyst'
#
# TypeError: 'tuple' object does not support item assignment

# %%
# to make changes in tuple we use  casing to conver tuple to list then make changes and again list ti tuple

# %%
r
type(r)
# Out:
# tuple

# %%
s = list(r)
type(s)
# Out:
# list

# %%
s
# Out:
# ['data', 'science']

# %%
s[1]='Analyst'

# %%
s
# Out:
# ['data', 'Analyst']

# %%
r= tuple(s)

# %%
r                        # here we get our output
# Out:
# ('data', 'Analyst')

# %%
# addition of tuple

# %%
t1 =(10,20,30.,40)
t2 = ('robotics', 'scirnce')

# %%
t3 = t1+t2
print()
