# %%
# Arithmetic Operators in python

# %%
10+54
# Out:
# 64

# %%
99/3
# Out:
# 33.0

# %%
44*71
# Out:
# 3124

# %%
452/26

# %%
125-69
# Out:
# 56

# %%
22%2         # modulo, it returns result
# Out:
# 0

# %%
22%3
# Out:
# 1

# %%
2**2
# Out:
# 4

# %%
2**2
# Out:
# 4

# %%
3**3
# Out:
# 27

# %%
4**4
# Out:
# 256

# %%
5**5
# Out:
# 3125

# %%
6**6
# Out:
# 46656

# %%
10//3          # floor operation, it round up decimal
# Out:
# 3

# %%
10/3
# Out:
# 3.3333333333333335

# %%
-10//3
# Out:
# -4

# %%
#floor()

# %%
import math
print(math.floor(10.99))
# Out:
# 10

# %%
print(math.floor(10.99))
print(math.floor(-10.99))
# Out:
# 10
# -11

# %%
# Comparative (Comparison) Operators

# %%
88==85
# Out:
# False

# %%
88!=99
# Out:
# True

# %%
78>99
# Out:
# False

# %%
78<99
# Out:
# True

# %%
77>=77
# Out:
# True

# %%
55<=55
# Out:
# True

# %%
# String Operations in Python using Comparison Operators

# %%
print("apple" == "apple")
# Out:
# True

# %%
print("apple" != "apple")
# Out:
# False

# %%
print("apple" > "banana")
# Out:
# False

# %%
print("apple" < "banana")
# Out:
# True

# %%
print("apple" >= "banana")
# Out:
# False

# %%
print("apple" <= "apple")
# Out:
# True
