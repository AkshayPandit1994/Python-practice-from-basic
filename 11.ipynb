# %% [markdown]
# split()
# strip()
# concatenation()
# format()
# f- string
# format & f-string also called as placeholder

# %%
for _ in range(10):
    print('Hello There')
# Out:
# Hello There
# Hello There
# Hello There
# Hello There
# Hello There
# Hello There
# Hello There
# Hello There
# Hello There
# Hello There

# %% [raw]
# When to use _
#
# Use _ when:
#
# You don’t need the loop variable
# You just want repetition
# Why _?
# _ means: "I don’t care about this value"

# %% [markdown]
# # split()

# %%
txt = "India is my country"

# %%
splt = txt.split()  # it returnss list
print(splt)
# Out:
# ['India', 'is', 'my', 'country']

# %%
sts = 'Python'                     # need at least 2 strings to see the result
print(sts.split())
# Out:
# ['Python']

# %%
e= 'Python is easy as compare to other language'
print(e.split())
# Out:
# ['Python', 'is', 'easy', 'as', 'compare', 'to', 'other', 'language']

# %%
e= 'Python is easy as compare to other language'
print(e.split(","))
# Out:
# ['Python is easy as compare to other language']

# %%
f = 'MAHA, RAJAS, TAMIL, ASSAM'                  # it creates seperate values where it sees comma
print(f.split(','))
# Out:
# ['MAHA', ' RAJAS', ' TAMIL', ' ASSAM']

# %%
t= 'data'
print(t.split(','))
# Out:
# ['data']

# %%
t= 'd,a,t,a'                 # it will split & split and return 
print(t.split(','))
# Out:
# ['d', 'a', 't', 'a']

# %%
w= 'the great Indian culture'
print(w.split(' ',2))               # it will split 2 string
# Out:
# ['the', 'great', 'Indian culture']

# %%
r= '10-20-30-40-50-60-70'
s= r.split('-')
print(s)
# Out:
# ['10', '20', '30', '40', '50', '60', '70']

# %%
nums = list(map(int, s))                   # map() “Apply this function to every item”,   Here: int is applied to each character
print(nums)
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
#example

# %%
y = '1,2,3,4,5'

# %%
num = list(map(int, y))
print(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 num = list(map(int, y))
#       2 print(num)
#
# ValueError: invalid literal for int() with base 10: ','

# %%
num = list(map(int, y.split(',')))
print(num)
# Out:
# [1, 2, 3, 4, 5]

# %%
s= ' 1,2,3,4,5,6'

# %%
pas= s.split(',')
print(pas)
# Out:
# [' 1', '2', '3', '4', '5', '6']

# %%
nim = [int(i) for i in pas]
print(nim)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
nim = [int(i.strip()) for i in pas]
print(nim)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = 'line1\nline2\nline3'
print(a)
# Out:
# line1
# line2
# line3

# %%
result = a.split('\n')
print(result)
# Out:
# ['line1', 'line2', 'line3']

# %%
b='Python'

# %%
result =list(b)                 # it will print each string, and o/p is horizontal
print(result)
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %%
for i in b:                     # # it also  print each string, and o/p is vertical
    print(i)
# Out:
# P
# y
# t
# h
# o
# n

# %%
name,age = input('Print Name & age: ').split()
print(name)
print(age)
# Out:
# Print Name & age:      Raj       33
# Raj
# 33

# %% [markdown]
# # Concatenation

# %%
a= 'Python'
b= 'SQL'

# %%
print(a + ' plus ' + b +' Step towards data analyst')
# Out:
# Python plus SQL Step towards data analyst

# %%
c= a + ' plus ' + b +' Step towards data analyst'
print(c)
# Out:
# Python plus SQL Step towards data analyst

# %%
name= 'Python'
msg = 'Welcome to the most popular language ' + name
print(msg)
# Out:
# Welcome to the most popular language Python

# %%
yr= 25
ms= 'My name is Jay & i am '+ yr + 'yrs old'         # can not add number + string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 2
#       1 yr= 25
# ----> 2 ms= 'My name is Jay & i am '+ yr + 'yrs old'
#
# TypeError: can only concatenate str (not "int") to str

# %%
yr= 25
ms= 'My name is Jay & i am '+ str(yr) + ' yrs old'  
print(ms)
# Out:
# My name is Jay & i am 25 yrs old

# %%
# Using , in print() (Not True Concatenation)

# %%
name = 'Abhishek'
prof = 'Cricketer'

# %%
print('Name is:', name, " & my Profession is:", prof)           # This is printing, not real concatenation
# Out:
# Name is: Abhishek  & my Profession is: Cricketer

# %%
# using format()

# %%
name= 'Himesh'
Age= 4

# %%
txt = 'My name is {} and i am {} years old'.format(name, Age)  #  no need to convert to  other 
print(txt)
# Out:
# My name is Himesh and i am 4 years old

# %%
# using f - string

# %%
name= 'Datta'
Age= 19

# %%
print(f'My Name is {name} & i am {Age} years old, thanks! ')
# Out:
# My Name is Datta & i am 19 years old, thanks!

# %%
# list concatenation

# %%
l1= [10,20,30,40]
l2 = [1,2,3,4]
l3 = l1+l2
print(l3)
# Out:
# [10, 20, 30, 40, 1, 2, 3, 4]

# %%
l3 = l2+l1             # whichever is 1st will come first
print(l3)
# Out:
# [1, 2, 3, 4, 10, 20, 30, 40]

# %%
msg = 'I love Python'
print(msg*5)
# Out:
# I love PythonI love PythonI love PythonI love PythonI love Python

# %%
msg = 'I love Python '
print(msg*5)
# Out:
# I love Python I love Python I love Python I love Python I love Python

# %%
msg = 'I love Python, '          # we can get output by making changes in string
print(msg*5)
# Out:
# I love Python, I love Python, I love Python, I love Python, I love Python,

# %%
# placeholder: %, format(), f-string

# %s = for string
# %d = for integer
# %f = for float

# %%
msg= 'I am robot born in early'
yr= 2000

# %%
print('%s, %d' %(msg, yr))
# Out:
# I am robot born in early, 2000

# %%
f= 'Ramesh'
a= 21

# %%
msg = 'my name is {} & i am {} years old'.format(f,a)
print(msg)
# Out:
# my name is Ramesh & i am 21 years old

# %%
txt = "Name:{0}, Age:{1}".format(f,a)
print(txt)
# Out:
# Name:Ramesh, Age:21

# %%
txt = "Name:{1}, Age:{0}".format(f,a)
print(txt)
# Out:
# Name:21, Age:Ramesh

# %%
text = 'Name:{aa}, Age:{ab}'.format(aa=f, ab=a)
print(text)
# Out:
# Name:Ramesh, Age:21

# %%
data= "I am in private  sector since"
year= 2025

msg='{data}, {year}'          # without ;f'
print(msg)
# Out:
# {data}, {year}

# %%
data= "I am in private  sector since"
year= 2025

msg=f'{data}, {year}'          # with 'f'
print(msg)
# Out:
# I am in private  sector since, 2025

# %%
a=10
b=12
print(f'sum of a + b is',{a+b})        # o/p is not clear
# Out:
# sum of a + b is {22}

# %%
print(f' sum of a+b is {a+b}')          # o/p is much clear
# Out:
#  sum of a+b is 22

# %%
pi = 3.1459
print(f'value of pi is {pi:.2f}')
# Out:
# value of pi is 3.15

# %%
print(f'value of pi is {pi:.2}')
# Out:
# value of pi is 3.1

# %%
print(f'value of pi is {pi:2f}')
# Out:
# value of pi is 3.145900

# %%
print(f'value of pi is {pi}')
# Out:
# value of pi is 3.1459

# %%
name = input('Enter your name: ').strip()
salary = input('Enter your salary:').strip()
msg = f'Your name is {name}, your salary is {salary}'
print(msg)
# Out:
# Enter your name:  Neha
# Enter your salary: $32000
# Your name is Neha, your salary is $32000
