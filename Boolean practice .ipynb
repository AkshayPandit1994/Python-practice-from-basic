# %%
# check student pass or fail

marks = 95

result = marks >= 35

print(result)
# Out:
# True

# %%
marks = int(input('Enter marks: '))

if marks >= 35:
    print('Pass')
else:
    print('Fail, please try hard again!')
# Out:
# Enter marks:  34
# Fail, please try hard again!

# %%
# Check high salary employee

salary = 99999

high_salary = salary >= 100000

print(high_salary)
# Out:
# False

# %%
# Check valid email

email = '123@python.com'

valid_email = '@' in email and '.com' in email

print(valid_email)
# Out:
# True

# %%
# Filter customers above age 30

customer_age = 30

age = customer_age >= 30 

print(age)
# Out:
# True

# %%
# Find negative reviews

review = input('Enter your review: ')

negative_words = ['bad','disappoint','frustate','poor','fraud']

result = any(word in review.lower() for word in negative_words)

print(result)
# Out:
# Enter your review:  very bad service
# True

# %%
# Detect fraud transaction   

amount = int(input('Enter amount: '))
location = input('Enter location')

fraud_transaction = amount >= 100000 and location == 'abroad', 'foreign'    # location will create tuple and notmultiple conditions see below correction

print(fraud_transaction)
# Out:
# Enter amount:  200000
# Enter location abroad
# (True, 'foreign')

# %%
amount = int(input('Enter amount: '))
location = input('Enter location')

fraud_transaction = amount >= 100000 and (location == 'abroad' or location == 'foreign')     # see diffrenrce in o/p

print(fraud_transaction)
# Out:
# Enter amount:  200000
# Enter location foreign
# True

# %%
# better versio

amount = int(input('Enter amount: '))
location = input('Enter location').lower()

fraud_transaction = amount >= 100000 and location in ['abroad','foreign']

print(fraud_transaction)
# Out:
# Enter amount:  200000
# Enter location FOREIGN
# True

# %%
name = 'AkshAY'

print(name.lower())
# Out:
# akshay

# %%
# Find inactive users

inactive_days = 39

result = inactive_days >= 40

print(result)
# Out:
# False

# %%
# better version

inactive_days = int(input('Enter incative days: '))

is_inactive = inactive_days >=25

print(is_inactive)
# Out:
# Enter incative days:  5
# False

# %%
# same program with if, else
inactive_days = int(input('Enter incative days: '))

if inactive_days >= 29:
    print('Yes, user is inactive!')
else:
    print('User is active')
# Out:
# Enter incative days:  28
# User is active

# %%
# Check product availability

product = input('Enter product: ')

avalibility = product in ['TV', 'Mobile', 'AC', 'Cooler', 'Projector']         # not getting o/p as per expectation as product in upper, lower case

print(avalibility)
# Out:
# Enter product:  tv
# False

# %%
# same progrom with lower product

product = input('Enter product: ').lower()

avalibility = product in ['tv', 'mobile', 'ac', 'cooler', 'projector']

print(avalibility)
# Out:
# Enter product:  AC
# True

# %%
# another version

product = input('Enter product: ').lower()

if product in ['tv', 'mobile', 'ac', 'cooler', 'projector']:
    print('Product available')
else:
    print('Product is not available right now')
# Out:
# Enter product:  samsung
# Product is not available right now

# %%
# Filter profitable products

products = input('Enter product: ')
profit = int(input('Enter profit: '))

result = profit > 0

print(result)
# Out:
# Enter product:  ac
# Enter profit:  12
# True

# %%
products = input('Enter product: ')
profit = int(input('Enter profit: '))

if profit > 0:
    print('Product is profitable')
else:
    print('Product is not profitable')
# Out:
# Enter product:  aircraft
# Enter profit:  -1230
# Product is not profitable

# %%
# Detect duplicate names 

names = ['Akshay', 'Rahul', 'Priya', 'Rahul']

name = input('Enter name to check: ')

is_duplicate = names.count(name)

print(is_duplicate)
# Out:
# Enter name to check:  Rahul
# 2

# %%
# another version

names = ['akshay', 'rahul', 'priya', 'rahul']

name = input('Enter name to check: ').lower()

if names.count(name) > 1:
    print('Duplicate name')
else:
    print('Unique name')
# Out:
# Enter name to check:  AkshAY
# Unique name

# %%
names = ['akshay', 'rahul', 'priya', 'rahul']

name = input('Enter name to check: ').lower()

if names.count(name) > 1:
    print('Duplicate name'.count(name))
else:
    print('Unique name'.count(name))
# Out:
# Enter name to check:  rahul
# 0

# %%
# correct program

names = ['akshay', 'rahul', 'priya', 'rahul']

name = input('Enter name to check: ').lower()

count = names.count(name)

if names.count(name) > 1:
    print('Duplicate name', count)
else:
    print('Unique name',count)
# Out:
# Enter name to check:  rahul
# Duplicate name 2

# %%
# another way of same program

names = ['akshay', 'rahul', 'priya', 'rahul']

name = input('Enter name to check: ').lower()

count = names.count(name)

print('Count of name: ', count)

if names.count(name) > 1:
    print('Duplicate name')
else:
    print('Unique name')
# Out:
# Enter name to check:  rahul
# Count of name:  2
# Duplicate name
