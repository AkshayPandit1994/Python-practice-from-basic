# %% [raw]
# # a boolean has only 2 values: True False
#
# 1. What is Boolean in Python?
#
# Boolean represents:
#
# Yes / No
# True / False
# 1 / 0
# Pass / Fail
# Valid / Invalid
#
# Boolean from comparision
#
# | Operator | Meaning          |
# | -------- | ---------------- |
# | `==`     | Equal            |
# | `!=`     | Not equal        |
# | `>`      | Greater than     |
# | `<`      | Less than        |
# | `>=`     | Greater or equal |
# | `<=`     | Less or equal    |
#
# Boolean with logican operators:
# | Operator | Meaning                |
# | -------- | ---------------------- |
# | `and`    | Both conditions True   |
# | `or`     | Any one condition True |
# | `not`    | Opposite value         |
#
#
# # some values automatically become false, below are false values
#
# False
# 0
# 0.0
# ''
# []
# {}
# None

# %%
is_student = True
is_salaried = False

print(is_student)
print(type(is_student))
# Out:
# True
# <class 'bool'>

# %%
salary  = 95000

print(salary > 50000)
# Out:
# True

# %%
# salary filter

salary = 95000

high_salary = salary > 75000

print(high_salary)
# Out:
# True

# %%
# pass faill analysis

marks = 35

is_pass = marks >= 35

print(is_pass)
# Out:
# True

# %%
# sales target achievement

sales = 12000
target = 11000

target_achieved = sales >= target

print(target_achieved)
# Out:
# True

# %%
# Age eligibility

age = 17.9

eligible_age = age >= 18

print(eligible_age)
# Out:
# False

# %%
# data validation

email = '123pythonpython.com'

valid = '@' in email and '.com' in email

print(valid)
# Out:
# False

# %%
# AND operator

salary = 5000
experience = 5 

eligible = salary >= 59000 and experience >= 4 

print(eligible)
# Out:
# False

# %%
# OR operator

city = 'NYC'

result = city == 'Mumbai' or city == 'Pune'

print(result)
# Out:
# False

# %%
# NOT operarator: reverse result

is_active = True

print(not is_active)
# Out:
# False

# %%
# Boolean in if condditions

salary = 89000

if salary >= 75000:
    print('High salaried emaployee')
# Out:
# High salaried emaployee

# %%
salary = int(input('Enter salary amount: '))

if salary >= 75000:
    print('High salaried employee')
else:
    print('Salaried employee')
# Out:
# Enter salary amount:  95000
# High salaried employee

# %%
# boolean in loops:

active= True

while active:
    print('running')
    active = False
# Out:
# running

# %%
# boolean from membership check

review = 'this product is bad'

if 'bad' in review:
    print('Negative')                 # its not boolean
# Out:
# Negative

# %%
review = 'this product is bad'

print('bad' in review)            # # its  boolean
# Out:
# True

# %%
# boolean with lists

marks = [63,78,100,80]

for i in marks:
    print(i>=75)
# Out:
# False
# True
# True
# True

# %%
# boolean in Pandas

import pandas as pd

data = {
    'name': ['Akshay','Rahul','Tanya'],
    'salary': [100000,59000,61000]
}

df = pd.DataFrame(data)

print(df['salary'] > 60000)
# Out:
# 0     True
# 1    False
# 2     True
# Name: salary, dtype: bool

# %%
# boolean is false for below values

print(bool(False))
print(bool(0))
print(bool(0.00))
print(bool(''))
print(bool([]))
print(bool({}))
print(bool(None))
# Out:
# False
# False
# False
# False
# False
# False
# False

# %%
print(bool('False'))
# Out:
# True

# %%
# boolean in KPI dashboard

profit = 1

is_profit = profit > 0

print(is_profit)
# Out:
# True

# %%
# fraud detection  example

amount = 100002
location = 'Foreign'

fraud = amount > 100001 and location == 'Foreign'

print(fraud)
# Out:
# True

# %%
# customer churn example

days_inactive = 120

churn = days_inactive > 90

print(churn)
# Out:
# True

# %%
# sentiment analysis

review = 'just '

positive_words = ['excellent', 'amazing', 'wow', 'geneous' ]

result = any (word in review.lower() for word in positive_words)

print(result)
# Out:
# False
