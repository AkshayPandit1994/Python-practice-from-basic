# %% [markdown]
# # Variables in Python:

# %%
age = 12 # integer
price = 100.96 # decimal

type(age),
type(price)
# Out:
# float

# %%
type(age),
# Out:
# (int,)

# %%
name = 'Python'
City = "NYC"

# %%
name
# Out:
# 'Python'

# %%
city       # case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 city
#
# NameError: name 'city' is not defined

# %%
City

# %%
type(name)
# Out:
# str

# %%
type (City)
# Out:
# str

# %%
male = False
Female = True

# %%
male
# Out:
# False

# %%
type(male)
# Out:
# bool

# %%
Female
# Out:
# True

# %%
type(Female)
# Out:
# bool

# %%
marks = [78,98,66,88,72]

# %%
marks
# Out:
# [78, 98, 66, 88, 72]

# %%
type(marks)
# Out:
# list

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
type(type)
# Out:
# type

# %%
a,b,c,d = 10,15,20,25
print(a,b,c,d)
# Out:
# 10 15 20 25

# %%
name = "Akshay"
marks = 97

print(name, 'got' ,marks, 'marks')
# Out:
# Akshay got 97 marks

# %%
city = "NYC"
city
# Out:
# 'NYC'

# %%
# operation perform on string

# %%
name = 'Python'

# %%
print(name.upper())
# Out:
# PYTHON

# %%
print(name.lower)
# Out:
# <built-in method lower of str object at 0x00000226F2034E70>

# %%
print(name.lower())
# Out:
# python

# %%
print(len(name))
# Out:
# 6

# %%
print(name[1])
# Out:
# y

# %%
print(name[-1])
# Out:
# n

# %%
print(name[1:])
# Out:
# ython

# %%
print(name[:-1])
# Out:
# Pytho

# %%
print(name[-5:-1])
# Out:
# ytho

# %%
marks=  [80,83,94]
marks
# Out:
# [80, 83, 94]

# %%
marks.reverse()

# %%
marks
# Out:
# [94, 83, 80]

# %%
marks.append(100)
marks
# Out:
# [94, 83, 80, 100]

# %%
marks.count(100)     # returns no of occurance of values
# Out:
# 1

# %%
marks.extend(105)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 marks.extend(105)
#
# TypeError: 'int' object is not iterable

# %%
marks.extend([105])

# %%
marks
# Out:
# [94, 83, 80, 100, 105]

# %%
marks.extend((109,))

# %%
marks
# Out:
# [94, 83, 80, 100, 105, 105, 109]

# %%
marks.sort()   #sorted inascending order

# %%
marks
# Out:
# [80, 83, 94, 100, 105, 105, 109]

# %%
marks.pop()
# Out:
# 109

# %%
marks.pop(0)
# Out:
# 80

# %%
marks
# Out:
# [83, 94, 100, 105, 105]

# %%
a= marks.copy()

# %%
a
# Out:
# [83, 94, 100, 105, 105]

# %%
marks.remove(105)

# %%
marks
# Out:
# [83, 94, 100, 105]

# %%
marks.index(100)
# Out:
# 2

# %%
marks
# Out:
# [83, 94, 100, 105]

# %%
marks.clear
# Out:
# <function list.clear()>

# %%
marks.clear()

# %%
marks
# Out:
# []

# %%
a
# Out:
# [83, 94, 100, 105, 105]

# %%
a= marks

# %%
marks
# Out:
# []

# %%
marks=a.copy()

# %%
marks
# Out:
# []

# %%
a
# Out:
# []

# %%
marks = [83, 94, 100, 105]

# %%
a= marks

# %%
marks
# Out:
# [83, 94, 100, 105]

# %%
a
# Out:
# [83, 94, 100, 105]

# %%
e = 1 + 5j

# %%
e.imag
# Out:
# 5.0

# %%
e.real
# Out:
# 1.0

# %%
e.conjugate()
# Out:
# (1-5j)

# %%
e
# Out:
# (1+5j)

# %%
f=2+9j

# %%
f
# Out:
# (2+9j)

# %%
print(e+f)
print(e-f)
print(e/f)
print(e*f)
# Out:
# (3+14j)
# (-1-4j)
# (0.5529411764705883+0.011764705882352946j)
# (-43+19j)

# %%
type(f)
# Out:
# complex

# %%
a= "Python"
b= "Popular"
c = 'Language'

# %%
print(a + 'is' + b +'programming'+ c)
# Out:
# PythonisPopularprogrammingLanguage

# %%
print(a + " " +'is' +" " + b +" " +'programming'+ " "+c)
# Out:
# Python is Popular programming Language

# %%
a = "i like python"
print(a*3)
# Out:
# i like pythoni like pythoni like python

# %%
a = "i like python!. "
print(a*3)
# Out:
# i like python!. i like python!. i like python!.

# %%
print(len(a))
# Out:
# 16

# %%
a
# Out:
# 'i like python!. '

# %%
a.upper()
# Out:
# 'I LIKE PYTHON!. '

# %%
a.strip()                     # strip()
# Out:
# 'i like python!.'

# %%
name= "Bharat"

# %%
name.replace("Bharat", "Hindustan, India")        # replace
# Out:
# 'Hindustan, India'

# %%
name
# Out:
# 'Bharat'

# %%
h= "Pandit"
h='B'+h[1:]
h
# Out:
# 'Bandit'

# %%
h= "Pandit"
h='B'+h[0:]
h
# Out:
# 'BPandit'

# %%
h
# Out:
# 'BPandit'

# %%
# challanges

# %%
# Personal Info
name = "Akshay"
age = 25
height = 5.8
is_student = False

# %%
print(name, age, height, is_student)         # prints all variables
# Out:
# Akshay 25 5.8 False

# %%
print(type(name), type(age), type(height), type(is_student))       #     # prints type of all variables
# Out:
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>

# %%
age = str(age)         # convert age to str

# %%
type(age)
# Out:
# str

# %%
# Product Info
product_name = "Laptop"
price = 55000
discount = 10  # in %
in_stock = True

# %%
final_price = price - (price * discount / 100)
final_price
# Out:
# 49500.0

# %%
Stock = "TV", 'mobile', 'laptop'

if 'laptop' in Stock:
    print ("available")
else:
    print( "not available")
# Out:
# available
