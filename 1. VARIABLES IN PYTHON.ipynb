# %%
name= 'Python'

# %%
name
# Out:
# 'Python'

# %%
age = 22

# %%
print(age)
# Out:
# 22

# %%
age
# Out:
# 22

# %%
# basic variable creation

# %%
name= 'Akshay'
age= 22
salary = 110000

# %%
print(name, age, salary)
# Out:
# Akshay 22 110000

# %%
print(name)
print(age)
print(salary)
# Out:
# Akshay
# 22
# 110000

# %% [markdown]
# # rules

# %%
# valid
name='akshay'
_age=22
salary2025 =900000
org_name = 'GSC'

# %%
# invalid 

2name='akshay'
emp-id = 123456
class = 'python'

# Why?

# cannot start with number
# hyphen - not allowed
# reserved keywords not allowed
# Out:
#   Cell In[11], line 3
#     2name='akshay'
#     ^
# SyntaxError: invalid decimal literal

# %%
# MULTIPLE VARIABLE ASSIGNMENT

a,b,c = 11,12,13

print(a,b,c)
print(a)
print(b)
print(c)

# %%
# assign same value

e=f=g = 99

print(e,f,g)

# %%
# variable swaping
# 1. traditional method

a=10
b=20
print(a, b)

swp = a
a=b
b=swp

print(a,b)

# %%
# 2.  python shortcut

a= 11
b= 12
print(a,b)

a,b= b,a

print(a,b)

# %%
u= 99
u='data'
u=23.36

print(u)        # it will execute last one

# %%
u= 99
u='data'
u='python'

print(u)

# %%
type(u)

# %%
print(type(u))

# %%
# MEMORY ADDRESS OF VARIABLE

id()

# %%
i = 'set'
print(id(i))    # it shows memory location

# %%
print(id(u))

# %%
# delete variable using del()

x= 10
print(x)

# %%
del x

# %%
print(x)           # variable is now deleted

# %%
# case sensative

name='akshay'
Name='rahul'
namE= 'rana'

print(name, Name, namE)
# all r diffrent variables

# %%
# reserved kyword can not use as variable

if = 100
for =20
class = 'python'

# %%
import keyword
print(keyword.kwlist)

# %%
import sys
print(sys.version)

# %%
import sys
print(sys.version)

# %%
import sys
print(sys.version)

# %%
# input variables

name = input('Enter your Name: ')
print('Your name is ', name)

# %%
# everything from input comes as string

age = input('Enter your age: ')
print(type(age))

# %%
# we can convert it manually

marks = int(input('enter your marks: '))
print(type(marks))

# %%
# VARIABLE TYPES BASED ON SCOPE

# 1. Local Variable: inside function

def data():
    r= 88              # varibles is inside
    print(r)
data()

# %%
# 2. Global Variable: outside function

f= 100            # outside mentioned

def data():
    print(f)
data()

# %%
#global keywword: modify global variable

w= 1400

def change():
    global w
    w=1500

change()

print(w)

# %%
# constants in python: python has no true constants

PI = 3.14
MAX_USERS = 100

# %%
print(id(PI))

# %% [markdown]
# # Data Types in Python

# %% [markdown]
# MAIN DATA TYPES
#
# | Type     | Example  |
# | -------- | -------- |
# | int      | 10       |
# | float    | 10.5     |
# | complex  | 2+3j     |
# | str      | "Python" |
# | bool     | True     |
# | list     | [1,2,3]  |
# | tuple    | (1,2,3)  |
# | set      | {1,2,3}  |
# | dict     | {"a":1}  |
# | NoneType | None     |

# %%
# 1. integer(whole numbers)

q= 99
p=55
d=0

# %%
print(q+p)

# %%
print(q*p)

# %%
print(q*d)

# %%
print(d/q)

# %%
print(q/d)

# %%
# python supports large numbers

e = 99999999999999999999999999999999999999999999999999999999999999999999999
print(e)

# %%
#2. float : decimal numbers

petrol_price= 107.65
pi=3.14

# %%
a= print(0.2+0.1)                 # output appears large due to binary floating point representation
print(a)

# %%
print(round(a,2))

# %%
t = 0.2+0.1

# %%
print(t)

# %%
print(round(t,3))

# %%
round

# %%
pi = 3.14159

# %%
print(pi)

# %%
print(round(pi,3))            # it will print 3 digits after decimal

# %%
# 3. Complex numbr: used in mathematic/scientific computing

# %%
g= 6+5j

# %%
type(g)

# %%
g.imag                       # it returns imaginary part

# %%
g.real            # it returns real part

# %%
g.conjugate

# %%
g.conjugate()                # it returns oposite operation of complex numbers

# %%
# 4. String

# %%
name='python'
city = 'Pune'

# %%
name[0]

# %%
name[1]

# %%
city[0]

# %%
city[1]

# %%
# negative indexing

# %%
name[-1]

# %%
name[-2]

# %%
city[-1]

# %%
city[-2]

# %%
# string slicing

name[:3]

# %%
name[3:]

# %%
city[0:]

# %%
city[1:3]

# %%
city[::-1]               # complete reverse

# %%
# string methods

name= 'India'

print(name.upper)

# %%
print(name.upper())
print(name.lower())
name.title()
name.capitalize()

# %%
name.center(5)

# %%
name.center(1)

# %%
# immutable string

# %%
name= 'python'

# %%
name[0]

# %%
name[0]='P'

# %%
# 5. Boolean: true, false

# %%
print(1==1)

# %%
print(1==3)

# %%
print(23%2 ==0)

# %%
print(24%2 ==0)

# %%
print(10>5)

# %% [raw]
# # TRUTHY & FALSY VALUES
#
# 0
# 0.0
# ''
# []
# {}
# None
# False
#
# Everything else --> true
#
# see below eamples

# %%
if []:
    print('yes')
else:
    print('No')

# %%
if {}:
    print('yes')
else:
    print('No')

# %%
if [0.0]:
    print('yes')
else:
    print('No')

# %%
if [0]:
    print('yes')
else:
    print('No')

# %%
if '':
    print('yes')
else:
    print('No')

# %%
if None:
    print('yes')
else:
    print('No')

# %%
if False:
    print('yes')
else:
    print('No')

# %%
# 6. List: mutable collection

# %%
nums = [0,2,3,4,5]

# %%
print(type(nums))

# %%
type(nums)

# %%
nums[0]

# %%
nums[0]=1          # we can replace list which is mutable
print(nums)

# %%
nums.append(5.5)
print(nums)

# %%
nums.clear

# %%
nums

# %%
nums.clear()      # it clear list and return blank list

# %%
nums

# %%
data = [10,20,30,40,50]

# %%
data.copy

# %%
data.copy()

# %%
data

# %%
data.count(30)

# %%
data.index(40)

# %%
data.insert(2,25)
data

# %%
data

# %%
data.pop()
data

# %%
data.remove(25)
data

# %%
data.reverse()
data

# %%
data.sort()
data

# %%
asc = [7,4,6,9,2,8,7,1,233,6,9,2,4,5]

# %%
asc.sort()
asc

# %%
asc.sort()
asc

# %% [markdown]
# # nested list

# %%
r= [5,6,7,8,9,[6,9,12,3],4,8]

# %% [markdown]
# r

# %%
r[0]

# %%
r[5]

# %%
r[5][0]

# %%
r[5][1]

# %%
r[5][2]

# %%
print(r[5][2])

# %%
alpha=['a','b','x','t','h','j','u']

# %%
alpha.append('y')
alpha
# Out:
# ['a', 'b', 'x', 't', 'h', 'j', 'u', 'y']

# %% [markdown]
# # 7. Tuple

# %%
# immutable colletion

# %%
t = (5)        # 1 value will be integetr and not tuple

# %%
type(t)
# Out:
# int

# %%
t = (5,)
type(t)
# Out:
# tuple

# %%
t= ()

if t == ():
    print('Tuple is blank')
else:
    print('not blank')
# Out:
# Tuple is blank

# %%
t=()

if not t:
    print('blank')
else:
    print('not blank')
# Out:
# blank

# %% [raw]
# # explanation
#
# ⚙️ Step-by-Step BreakdownWhen
# Python executes if not t: with an empty tuple t = ():Python evaluates the truth value of t.
# Because t is an empty tuple, it evaluates to False.The not operator reverses this value: not False becomes True.
# Since the condition is now True, the if block triggers and prints 'Tuple is blank'.

# %%
tu= (15,16,14,12)
print(tu)
# Out:
# (15, 16, 14, 12)

# %%
print(tu[0])
# Out:
# 15

# %%
print(tu(0))          # we have to use [] to call tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(tu(0))
#
# TypeError: 'tuple' object is not callable

# %%
tu
# Out:
# (15, 16, 14, 12)

# %%
tu[0]
# Out:
# 15

# %%
tu[1]
# Out:
# 16

# %%
tu[1]=17
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 tu[1]=17
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # 8. set{}

# %%
# unique unordered values

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s = {1,}
print(type(s))
# Out:
# <class 'set'>

# %%
type(s)
# Out:
# set

# %%
se= {10,20,30,30,40,50}    # it removes duplicate
se
# Out:
# {10, 20, 30, 40, 50}

# %%
print(se)          # order chaned
# Out:
# {50, 20, 40, 10, 30}

# %%
se.add(60)
se
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
sd={9,6,88,22,10,20,30}

# %%
se.difference(sd)
# Out:
# {40, 50, 60}

# %%
sd.difference(se)
# Out:
# {6, 9, 22, 88}

# %%
se
sd
# Out:
# {6, 9, 10, 20, 22, 30, 88}

# %%
print(se)
print(sd)
# Out:
# {50, 20, 40, 10, 60, 30}
# {20, 6, 22, 88, 9, 10, 30}

# %%
se.difference_update(sd)      # here only o/p not change, complete set change from {50, 20, 40, 10, 60, 30} to {40, 50, 60}
se
# Out:
# {40, 50, 60}

# %%
sd.difference_update(se)
sd
# Out:
# {6, 9, 10, 20, 22, 30, 88}

# %%
se                # complete change in set
# Out:
# {40, 50, 60}

# %%
print(se)
print(sd)
# Out:
# set()
# {20, 6, 22, 88, 9, 10, 30}

# %%
se.discard(60)
se
# Out:
# set()

# %%
se
# Out:
# set()

# %%
se.discard(70)         # it will not give an error even 70 is not member of set
se
# Out:
# set()

# %%
se.intersection(sd)      # returns blank  set as nothing is common in both sets
# Out:
# set()

# %%
se
# Out:
# set()

# %%
sd
# Out:
# {6, 9, 10, 20, 22, 30, 88}

# %%
se.intersection_update(sd)
se
# Out:
# set()

# %%
se.isdisjoint
# Out:
# <function set.isdisjoint(other, /)>

# %%
se.isdisjoint(sd)
# Out:
# True

# %%
print(se)
print(sd)
# Out:
# set()
# {20, 6, 22, 88, 9, 10, 30}

# %%
se.issubset(sd)

# It returns True because of a fundamental mathematical rule: the empty set is always a subset of any other set.
# Out:
# True

# %%
a= {1,2,3,4}
b= {3,4,5,6}

print(a)
print(b)

type(a)
type(b)
# Out:
# {1, 2, 3, 4}
# {3, 4, 5, 6}
# set

# %%
a.issubset(b)
# Out:
# False

# %%
a.issuperset(b)
# Out:
# False

# %%
b.issuperset(a)

# a is a superset of b only if a contains all the elements of b (plus potentially more).
# Reason: The elements 5 and 6 belong to b, but they are missing from a.Result: False
# Out:
# False

# %%
a.pop()   # it remove element
# Out:
# 1

# %%
a
# Out:
# {2, 3, 4}

# %%
b
# Out:
# {3, 4, 5, 6}

# %%
b.pop()
b
# Out:
# {4, 5, 6}

# %%
print(a)
print(b)
# Out:
# {2, 3, 4}
# {4, 5, 6}

# %%
a.remove(3)   # 3 removed here

# %%
a.remove(3)      # shows error  as 3 is not part of set a
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 a.remove(3)
#
# KeyError: 3

# %%
print(a)
print(b)
# Out:
# {2, 4}
# {4, 5, 6}

# %%
a.symmetric_difference(b)
# Out:
# {2, 5, 6}

# %%
a
# Out:
# {2, 4}

# %%
b.symmetric_difference_update(a)
b
# Out:
# {2, 5, 6}

# %%
print(a)
print(b)
# Out:
# {2, 4}
# {2, 5, 6}

# %%
print(a)
print(b)
# Out:
# {2, 4}
# {2, 5, 6}

# %%
a.union(b)
# Out:
# {2, 4, 5, 6}

# %%
print(a)
print(b)
# Out:
# {2, 4}
# {2, 5, 6}

# %%
a.update(b)
a
# Out:
# {2, 4, 5, 6}

# %%
print(a)
print(b)
# Out:
# {2, 4, 5, 6}
# {2, 5, 6}

# %%
a= {1,2,3}
b= {3,4,5}

print(a&b)         # print common element
print(a|b)         # print all unique elements in both sets
# Out:
# {3}
# {1, 2, 3, 4, 5}

# %% [markdown]
# # 9. Dictonary

# %%
# key, value pair

# %%
student = {
    'name': 'Akshay',
    'age': 22
}

# %%
student
# Out:
# {'name': 'Akshay', 'age': 22}

# %%
print(student)
# Out:
# {'name': 'Akshay', 'age': 22}

# %%
type(student)
# Out:
# dict

# %%
scl = {
    'name': 'AP school',
    'year': 2000
}

# %%
scl
# Out:
# {'name': 'AP school', 'year': 2000}

# %%
print(student)
print(scl)
# Out:
# {'name': 'Akshay', 'age': 22}
# {'name': 'AP school', 'year': 2000}

# %%
student.fromkeys(scl)
# Out:
# {'name': None, 'year': None}

# %%
print(student)
print(scl)
# Out:
# {'name': 'Akshay', 'age': 22}
# {'name': 'AP school', 'year': 2000}

# %%
dict.fromkeys(scl)
# Out:
# {'name': None, 'year': None}

# %%
print(student)
print(scl)
# Out:
# {'name': 'Akshay', 'age': 22}
# {'name': 'AP school', 'year': 2000}

# %%
student.get('name')
# Out:
# 'Akshay'

# %%
scl.get('year')
# Out:
# 2000

# %%
scl.items()
# Out:
# dict_items([('name', 'AP school'), ('year', 2000)])

# %%
student.items
# Out:
# <function dict.items()>

# %%
student.items()
# Out:
# dict_items([('name', 'Akshay'), ('age', 22)])

# %%
print(student)
print(scl)
# Out:
# {'name': 'Akshay', 'age': 22}
# {'name': 'AP school', 'year': 2000}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
scl.keys()
# Out:
# dict_keys(['name', 'year'])

# %%
a= {'country1': 'India', 'Country2': 'pak'}
a
# Out:
# {'country1': 'India', 'Country2': 'pak'}

# %%
type(a)
# Out:
# dict

# %%
a.pop('Country2') # it remove given key
# Out:
# 'pak'

# %%
a
# Out:
# {'country1': 'India'}

# %%
print(student)
print(scl)
# Out:
# {'name': 'Akshay', 'age': 22}
# {'name': 'AP school', 'year': 2000}

# %%
student.popitem()
# Out:
# ('age', 22)

# %%
print(student)
print(scl)
# Out:
# {'name': 'Akshay'}
# {'name': 'AP school', 'year': 2000}

# %%
scl.popitem()
# Out:
# ('year', 2000)

# %%
print(student)
print(scl)
# Out:
# {'name': 'Akshay'}
# {'name': 'AP school'}

# %%
student.setdefault('year')
scl.setdefault('est_year')

print(student)
print(scl)
# Out:
# {'name': 'Akshay', 'year': None}
# {'name': 'AP school', 'est_year': None}

# %%
student.update()

# %%
print(student)
# Out:
# {'name': 'Akshay', 'year': None}

# %%
student.values()
# Out:
# dict_values(['Akshay', None])

# %%
scl.values()
# Out:
# dict_values(['AP school', None])

# %%
student.keys
# Out:
# <function dict.keys()>

# %%
student.keys()
# Out:
# dict_keys(['name', 'year'])

# %%
scl.keys()
# Out:
# dict_keys(['name', 'est_year'])

# %% [markdown]
# # 10. None type

# %%
# represnts absence of value

# %%
x= None

# %%
type(x)
# Out:
# NoneType

# %%
# type of conversaion
# 1. Implicit conversion
# 2. Explicit conversaion

# %%
# 1. Implicit conversion

print(9+8.6)              # python converts automatically
# Out:
# 17.6

# %%
# 2. Explicit conversaion

d= '1000'
print(d)
print(type(d))
# Out:
# 1000
# <class 'str'>

# %%
print(int(d))
# Out:
# 1000

# %%
print(type(d))
# Out:
# <class 'str'>

# %%
# string to integer conversion

x = int('22')
type(x)
# Out:
# int

# %%
r = '3600'
type(r)
# Out:
# str

# %%
q= int(r)
print(q)
# Out:
# 3600

# %%
type(q)
# Out:
# int

# %%
# int to float conversion

a= 10
print(a)
print(type(a))

j= float(a)
print(j)
print(type(j))
# Out:
# 10
# <class 'int'>
# 10.0
# <class 'float'>

# %%
# float to int conversion

a= 10.78
print(a)
print(type(a))

j= int(a)
print(j)
print(type(j))
# Out:
# 10.78
# <class 'float'>
# 10
# <class 'int'>

# %%
# list to tuple conversion

w= [10,20,30,40]
type(w)
# Out:
# list

# %%
t= tuple(w)
type(t)
# Out:
# tuple

# %%
z = [7,8,9,10]
z=tuple(z)
type(z)
# Out:
# tuple

# %%
MUTABLE VS IMMUTABLE

| Mutable | Immutable |
| ------- | --------- |
| list    | tuple     |
| dict    | str       |
| set     | int       |


Mutable → can change
Immutable → cannot change

# %%
a= [1,2]
b=a
a.append(3)

print(b)
print(a)
# Out:
# [1, 2, 3]
# [1, 2, 3]

# %%
print(bool(''))
print(bool(' '))

# empty string is false, space is true
# Out:
# False
# True
