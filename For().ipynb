# %%
d=8

# %%
type(d)
# Out:
# int

# %%
a=b=c = 'Python coding'
print(a)
print(b)
print(c)
# Out:
# Python coding
# Python coding
# Python coding

# %%
ipl = ['SRH','MI','RR']
ipl
# Out:
# ['SRH', 'MI', 'RR']

# %%
s,t,u=ipl

# %%
print(s,t,u)
# Out:
# SRH MI RR

# %%
a,*b = [11,12,13,14,15]
print(a)
print(b)
# Out:
# 11
# [12, 13, 14, 15]

# %%
x,y=['i','j','k','l']                # to avoid this error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 x,y=['i','j','k','l']
#
# ValueError: too many values to unpack (expected 2)

# %%
x, *y=['i','j','k','l']

# %%
print(x)
print(y)
# Out:
# i
# ['j', 'k', 'l']

# %%
a= 'Python'
b= 'SQL'
c= 'Power BI'

# %%
Data_science = a + " " + b + " "+ c
Data_science
# Out:
# 'Python SQL Power BI'

# %%
a=  7
b= 'coding'
print(a+b)             # cannot add number + str
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 a=  7
#       2 b= 'coding'
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(a,b)         # no need to add + sign
# Out:
# 7 coding

# %%
a= str(7)     # we have conver it to str
b= 'coding'
print(a +" " +b)
# Out:
# 7 coding

# %%
txt= 'I like programing language, Python!'

# %%
print('love' in txt)          # check given txt in varibale
# Out:
# False

# %% [markdown]
# # for () excercise

# %%
# basic

# %%
for i in range(5):          # range(5) → starts from 0, ends at 4
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# custom range

# %%
for i in range(2,8):       # start, end-1
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7

# %%
# step value

# %%
for i in range(1,10,2):    # 1 to 9 with gap 2
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# reverse loop

# %%
for i in range(5,0,-1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
for i in range(5,0,-2):
    print(i)
# Out:
# 5
# 3
# 1

# %%
for i in range(5,0,1):      # it will not return anything
    print(i)

# %%
# loop through list

# %%
names = ['Akshay', 'Raj', 'Vicky']

# %%
for name in names:
    print(name)
# Out:
# Akshay
# Raj
# Vicky

# %%
# loop though string

# %%
for s in 'Akshay':
    print(s)
# Out:
# A
# k
# s
# h
# a
# y

# %%
# using enumerate

# %%
names = ['A','B','C']

for i,v in enumerate(names):
    print(i,v)
# Out:
# 0 A
# 1 B
# 2 C

# %%
# nested loop

# %%
for i in range(3):
    for j in range(3):
        print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2

# %%
# break

# %%
for i in range(6):
    if i == 4:
        break               # it will print till given value and exit
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(6):
    if i == 4:
        continue               # it will skip given number and print remainig
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 5

# %%
# pass

# %%
for i in range(5):
    pass                  # does nothing

# %%
# else with loop

# %%
for i in range(5):
    print(i)
else:
    print('Loop End!')
# Out:
# 0
# 1
# 2
# 3
# 4
# Loop End!

# %%
# loop with dict

# %%
data = {'name': "Rahul", 'age': 22}

for i in data:
    print(i)
# Out:
# name
# age

# %%
data = {'name': "Rahul", 'age': 22}
for i in data:
    print(i, data)
# Out:
# name {'name': 'Rahul', 'age': 22}
# age {'name': 'Rahul', 'age': 22}

# %%
data = {'name': "Rahul", 'age': 22}
for i in data:
    print(i, data[i])
# Out:
# name Rahul
# age 22

# %%
# iterating over data

# %%
number = [10,20,30,40]

for i in number:
    print(i*2)                # mutiply by 2 to given dataset
# Out:
# 20
# 40
# 60
# 80

# %%
# using index - when index is require

# %%
names = ['A','B','C']

for i in range(len(names)):
    print(i, names[i])
# Out:
# 0 A
# 1 B
# 2 C

# %%
# enumerate()

# %%
names = ['A','B','C']

for i, v in enumerate(names):
    print(i,v)
# Out:
# 0 A
# 1 B
# 2 C

# %%
# filtering data

nums = [4,8,12,16,20]

for n in nums:
    if n>10:
        print(n)
# Out:
# 12
# 16
# 20

# %%
# Searching

# %%
nums = [4,8,12,16,20]

for i in nums:
    if i == 25:
        print('Found!')
        break
    else:                      # incorrect indentation
        print('Missing')
# Out:
# Missing
# Missing
# Missing
# Missing
# Missing

# %%
# even the indentation matters

# %%
nums = [4,8,12,16,20]

for i in nums:
    if i == 16:
        print('Found!')
        break
else:
    print('Missing')
# Out:
# Found!

# %%
# counting occurrances

# %%
nums = [1,2,2,4,5,6,4,1]

count = 0

for n in nums:
    if n == 1:
        count = count + 1


print(count)
# Out:
# 2

# %%
########### how to add input value

# %%
strn = ['a','b','d','a','c','b']

count = 0

for i in strn:
    if i == 'c':
        count = count +1
print(count)
# Out:
# 1

# %%
# Accumulation(sum, total)

# %%
nums = [11,22,36,50,12]

total = 0

for i in nums:
    total = total + i      # or total += n
print(total)
# Out:
# 131

# %%
# pattern printting

# %%
for i in range(1,5):
    print('*' *i)
# Out:
# *
# **
# ***
# ****

# %%
# Iterating dictionary

# %%
data = {'name': "Rahul", 'age': 22}

for i,v in data.items():
    print(i,v)
# Out:
# name Rahul
# age 22

# %%
Marks = {}

# %%
type(Marks)
# Out:
# dict

# %%
Marks = {'SName': 'Nilam', 'mark': 90}

for i, v in Marks.items():
    print(i,v)
# Out:
# SName Nilam
# mark 90

# %%
# multiple lists together    zip()

# %%
a = [1,2,3]
b= ['a','b', 6]

for s, t in zip(a,b):
    print(s,t)
# Out:
# 1 a
# 2 b
# 3 6

# %%
# working with character

# %%
for c in 'Python':
    print(c.upper())
# Out:
# P
# Y
# T
# H
# O
# N

# %%
sqr = [i*i for i in range(2,9)]

# %%
print(sqr)
# Out:
# [4, 9, 16, 25, 36, 49, 64]

# %%
# nested + condition combo

# %%
for i in range(3):
    for j in range(3):
        if i ==j:
            print('*', end=' ')
        else:
            print('-', end= ' ')

    print()
# Out:
# * - -
# - * -
# - - *

# %%
# loop for input processing

# %%
nums=[]

for i in range(3):
    n = int(input("Enter number: "))
    nums.append(n)

print(nums)
# Out:
# Enter number:  10
# Enter number:  20
# Enter number:  30
# [10, 20, 30]

# %%
# loop validation

# %%
password = 'India@2026'

for i in range(3):
    user = input("Enter password: ")
    if user  == password:
        print("Access granted!")
        break
else:
    print('Aceess denied!')
# Out:
# Enter password:  India@2026
# Access granted!
