# %%
for i in range(6):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
s=['10,20,30,60,40,8,55,969,44,77,33,55']

# %%
for i in s:
    print(i)
# Out:
# 10,20,30,60,40,8,55,969,44,77,33,55

# %%
for i in range(2,10,3):
    print(i)
# Out:
# 2
# 5
# 8

# %%
for i in range(2,10,3):
    if i>7:
        print(i)
# Out:
# 8

# %%
for i in 'Python':
    print(i)
# Out:
# P
# y
# t
# h
# o
# n

# %%
for i in [9,8,7,6,5,4]:          # for with list
    print(i)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4

# %%
for i in (1,2,3,4,5,6):        # with tuple
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in {4,5,6,9,6,3,1,4,7, 'n','a','t','i','o'}:           # unorder, for with set
    print(i)
# Out:
# 1
# 3
# 4
# 5
# 6
# 7
# t
# 9
# i
# a
# o
# n

# %%
ndata = {'Name': 'India', 'IndpYear': 1947 }
print(ndata)
# Out:
# {'Name': 'India', 'IndpYear': 1947}

# %%
for i in ndata:                    # prints only keys
    print(i)
# Out:
# Name
# IndpYear

# %%
for i in ndata:
    print(i, ndata.values())
# Out:
# Name dict_values(['India', 1947])
# IndpYear dict_values(['India', 1947])

# %%
for v in ndata.values():              # prints only values
    print(v)
# Out:
# India
# 1947

# %%
for i, v in ndata.items():     # it returns whole dict
    print(i,v)
# Out:
# Name India
# IndpYear 1947

# %%
for i in range(6):
    print(i)
else:
    print('Loop end')
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# Loop end

# %%
# break()

# %%
for i in range(5):
    if i ==3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
# continue

# %%
for i in range(5):
    if i ==3:
        continue             # it will skip the i value
    print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
# range()

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
tuple(range(5))
# Out:
# (0, 1, 2, 3, 4)

# %%
set(range(5))
# Out:
# {0, 1, 2, 3, 4}

# %%
range(-6,0)
# Out:
# range(-6, 0)

# %%
print(range(-6,0))
# Out:
# range(-6, 0)

# %%
for i in range(-6,0):
    print(i)
# Out:
# -6
# -5
# -4
# -3
# -2
# -1

# %%
# strip()   remove spaces

# %%
name = ' Python    '
print(name)
# Out:
#  Python

# %%
name.strip()    # it removes whitespaces
# Out:
# 'Python'

# %%
# \n: new line, \t: tab

# %%
txt = '\n hello'
print(txt)
# Out:
#  hello

# %%
txt = '\n\t hello'
print(txt)
# Out:
# 	 hello

# %%
txt = '\n\t hello\t'
print(txt)
# Out:
# 	 hello

# %%
txt = '\n\t hello\t\n'
print(txt)
# Out:
# 	 hello

# %%
txt
# Out:
# '\n\t hello\t\n'

# %%
print(txt)
# Out:
# 	 hello

# %%
print(txt.strip())         # it removes white spaces
# Out:
# hello

# %%
sts = '#$#$#$# Python'
print(sts)
# Out:
# #$#$#$# Python

# %%
print(sts.strip('#$'))              # it remove whitespaces
# Out:
#  Python

# %%
# replace()

# %%
s= 'i like sql'
print(s)
# Out:
# i like sql

# %%
r = s.replace('sql', 'Python')
r
# Out:
# 'i like Python'

# %%
print(s)        # original string is as is
print(r)
# Out:
# i like sql
# i like Python

# %%
d= 'apple', 'b','a','a','c','d'
print(d)
# Out:
# ('apple', 'b', 'a', 'a', 'c', 'd')

# %%
e= d.count('a')
e
# Out:
# 2

# %%
f= 'banana', 'potato', 'cherry'
print(f)
# Out:
# ('banana', 'potato', 'cherry')

# %%
g=f.replace('banana', 'apple')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 g=f.replace('banana', 'apple')
#
# AttributeError: 'tuple' object has no attribute 'replace'

# %%
w= 'banana banana banana'
print(w)
# Out:
# banana banana banana

# %%
x=w.replace('banana', 'watermelon')
print(x)
# Out:
# watermelon watermelon watermelon

# %%
a= 'apple,apple,apple,apple,apple,'
print(a)
# Out:
# apple,apple,apple,apple,apple,

# %%
r=a.replace('apple', 'cherry', 2)            # it will replace only first 2 instances
print(r)
# Out:
# cherry,cherry,apple,apple,apple,

# %%
txt= '02-04-2026'
print(txt)
# Out:
# 02-04-2026

# %%
txt.replace('-','/')
# Out:
# '02/04/2026'

# %%
print(txt)
# Out:
# 02-04-2026

# %%
print(txt.replace('-','/'))
# Out:
# 02/04/2026

# %%
txt = 'Hello hello'
print(txt)
# Out:
# Hello hello

# %%
ft=txt.replace('hello', 'Hi there')     # case sensitive
print(ft)
# Out:
# Hello Hi there

# %%
name="John   Cena"
name
# Out:
# 'John   Cena'

# %%
print(name)
# Out:
# John   Cena

# %%
uname=name.replace(" ", "_")
print(uname)
# Out:
# John___Cena

# %%
sent = input('Enter a sentence:')
print(sent.replace('bad', 'good'))
# Out:
# Enter a sentence: Coding is very bad
# Coding is very good
